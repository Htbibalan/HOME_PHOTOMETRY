# %% [markdown]
# # In V3 of the code we were sending TTLs via 5 pin for Pellet intake(and pellet in well), Right poke, Left Poke, Rightwithpellet poke and Leftwithpellet poke, now I am trying to see whether we can easily send signals of pokes via the same pins
# # note that V4 was trying to make Raspberry Pi autmatically run the code --  while we decided to use a touch screen -- so V4 is archived and we proceed with V3 of the code.

# %%
#!/usr/bin/env python3

import os
import sys
import RPi.GPIO as GPIO
import serial
import threading
import datetime
import time
import logging
import traceback
import re

# Configure logging
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s [%(levelname)s] %(message)s',
    stream=sys.stdout
)

# Setup GPIO pins on the Raspberry Pi (BCM mode)
GPIO.setmode(GPIO.BCM)
GPIO.setwarnings(False)

# Define adjusted GPIO pins for each device 
gpio_pins_per_device = {
    'Port 1': {
        "LeftPoke": 17,        # GPIO17 (Physical Pin 11) - Left Poke and LeftWithPellet
        "RightPoke": 27,       # GPIO27 (Physical Pin 13) - Right Poke and RightWithPellet
        "Pellet": 22,          # GPIO22 (Physical Pin 15) - Pellet event
    },
    'Port 2': {
        "LeftPoke": 10,        # GPIO10 (Physical Pin 19) - Left Poke and LeftWithPellet
        "RightPoke": 9,        # GPIO9 (Physical Pin 21)  - Right Poke and RightWithPellet
        "Pellet": 11,          # GPIO11 (Physical Pin 23) - Pellet event
    },
    'Port 3': {
        "LeftPoke": 0,         # GPIO0 (Physical Pin 27)  - Left Poke and LeftWithPellet
        "RightPoke": 5,        # GPIO5 (Physical Pin 29)  - Right Poke and RightWithPellet
        "Pellet": 6,          # GPIO06 (Physical Pin 31) - Pellet event
    },
    'Port 4': {
        "LeftPoke": 13,        # GPIO13 (Physical Pin 33) - Left Poke and LeftWithPellet
        "RightPoke": 19,       # GPIO19 (Physical Pin 35) - Right Poke and RightWithPellet
        "Pellet": 26,          # GPIO26 (Physical Pin 37) - Pellet event
    },
}

# Set all pins as output and initially set them to LOW
for device_pins in gpio_pins_per_device.values():
    for pin in device_pins.values():
        GPIO.setup(pin, GPIO.OUT)
        GPIO.output(pin, GPIO.LOW)

# Create a lock for thread-safe access to shared variables
pellet_lock = threading.Lock()

# Track the state of Pellet in Well per port_identifier
pellet_in_well = {}  # Dictionary to keep track per port_identifier

# Global event to signal threads to stop
stop_event = threading.Event()

# Function to send TTL pulse for regular poke events
def send_ttl_signal(pin):
    logging.debug(f"Sending TTL signal to pin {pin}")
    GPIO.output(pin, GPIO.HIGH)
    time.sleep(0.01)  # Send a 10 ms pulse
    GPIO.output(pin, GPIO.LOW)

# Function to handle the PelletInWell/PelletTaken logic
def handle_pellet_event(event_type, port_identifier, gpio_pins):
    global pellet_in_well
    with pellet_lock:
        if port_identifier not in pellet_in_well:
            pellet_in_well[port_identifier] = False
        if event_type == "Pellet":
            if pellet_in_well[port_identifier]:
                GPIO.output(gpio_pins["Pellet"], GPIO.LOW)  # Pellet taken, turn the signal off
                logging.debug(f"{port_identifier}: Pellet taken, signal turned OFF.")
                pellet_in_well[port_identifier] = False  # Update state
                send_ttl_signal(gpio_pins["Pellet"])  # Send a short TTL pulse for PelletTaken
            else:
                logging.debug(f"{port_identifier}: No pellet was in the well, no signal for pellet taken.")
        elif event_type == "PelletInWell":
            GPIO.output(gpio_pins["Pellet"], GPIO.HIGH)  # Pellet in well, keep signal on
            pellet_in_well[port_identifier] = True
            logging.debug(f"{port_identifier}: Pellet dispensed in well, signal ON.")

# Function to process each event and send TTLs accordingly
def process_event(event_type, port_identifier, gpio_pins):
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")[:-3]
    logging.info(f"[{timestamp}] [{port_identifier}] Processing event: {event_type}")

    if event_type == "Left" or event_type == "LeftWithPellet":
        # Combine Left and LeftWithPellet using same signal
        send_ttl_signal(gpio_pins["LeftPoke"])
        logging.debug(f"{port_identifier}: Left poke event (with or without pellet) triggered.")

    elif event_type == "Right" or event_type == "RightWithPellet":
        # Combine Right and RightWithPellet using same signal
        send_ttl_signal(gpio_pins["RightPoke"])
        logging.debug(f"{port_identifier}: Right poke event (with or without pellet) triggered.")

    elif event_type in ["Pellet", "PelletInWell"]:
        handle_pellet_event(event_type, port_identifier, gpio_pins)  # Handle PelletInWell and PelletTaken

# Function to get device mappings based on physical USB ports
def get_device_mappings_by_usb_port():
    device_mappings = []

    # Define the mapping from USB port paths to port identifiers
    usb_port_mapping = {
        'usb-0:1.1': 'Port 1',
        'usb-0:1.2': 'Port 2',
        'usb-0:1.3': 'Port 3',
        'usb-0:1.4': 'Port 4',
        # Add more mappings if you have more USB ports
    }

    # List all symlinks in /dev/serial/by-path/
    for symlink in os.listdir('/dev/serial/by-path/'):
        symlink_path = os.path.join('/dev/serial/by-path/', symlink)
        serial_port = os.path.realpath(symlink_path)
        if 'ttyACM' in serial_port or 'ttyUSB' in serial_port:
            logging.debug(f"Found serial port {serial_port} with symlink {symlink}")

            # Extract the USB port path from the symlink
            usb_port_path = get_usb_port_path_from_symlink(symlink)
            if not usb_port_path:
                continue

            port_identifier = usb_port_mapping.get(usb_port_path)
            if port_identifier:
                device_mappings.append({
                    'serial_port': serial_port,
                    'port_identifier': port_identifier,
                })
                logging.info(f"Mapped serial port {serial_port} to {port_identifier} based on USB port {usb_port_path}")
            else:
                logging.warning(f"No mapping found for USB port {usb_port_path}")
        else:
            logging.warning(f"Symlink {symlink} does not point to a recognized serial port.")
    return device_mappings

def get_usb_port_path_from_symlink(symlink):
    # Extract the USB port path from the symlink name
    # e.g., 'platform-...-usb-0:1.1:1.0' -> 'usb-0:1.1'
    match = re.search(r'usb-\d+:\d+(\.\d+)*', symlink)
    if match:
        usb_port_path = match.group()
        return usb_port_path
    else:
        logging.warning(f"Could not extract USB port path from symlink {symlink}")
        return None

# Function to read from serial port (FED3 devices)
def read_from_fed(serial_port, port_identifier, gpio_pins):
    try:
        ser = serial.Serial(serial_port, 115200, timeout=1)
        logging.info(f"Opened serial port {serial_port} for {port_identifier}")
    except serial.SerialException as e:
        logging.error(f"Could not open serial port {serial_port}: {e}")
        return
    except Exception as e:
        logging.error(f"Unexpected error opening serial port {serial_port}: {e}")
        return

    try:
        while not stop_event.is_set():
            try:
                line = ser.readline().decode('utf-8').strip()
                if line:
                    data_list = line.split(",")
                    logging.debug(f"{port_identifier} raw data: {data_list}")
                    if len(data_list) >= 10:
                        event_type = data_list[9]
                        logging.debug(f"{port_identifier}: Extracted event type: {event_type}")
                        process_event(event_type, port_identifier, gpio_pins)
                    else:
                        logging.warning(f"{port_identifier}: Received incomplete data, skipping this line.")
                else:
                    # No data received; can implement a sleep or pass
                    pass
            except UnicodeDecodeError as e:
                logging.error(f"{port_identifier}: Decoding error on serial port {serial_port}: {e}")
            except Exception as e:
                logging.error(f"{port_identifier}: Error reading from serial port {serial_port}: {e}")
                logging.error(traceback.format_exc())
        ser.close()
        logging.info(f"Serial port {serial_port} for {port_identifier} closed.")
    except Exception as e:
        logging.error(f"Critical error in thread for serial port {serial_port}: {e}")
        logging.error(traceback.format_exc())
    finally:
        try:
            ser.close()
            logging.info(f"Serial port {serial_port} for {port_identifier} closed.")
        except Exception as e:
            logging.error(f"Error closing serial port {serial_port}: {e}")

# Main execution
if __name__ == "__main__":
    logging.info("Starting device mapping based on USB ports...")
    device_mappings = get_device_mappings_by_usb_port()

    if not device_mappings:
        logging.error("No FED3 devices found. Exiting.")
        sys.exit(1)

    threads = []

    # Start threads for each device
    for mapping in device_mappings:
        serial_port = mapping['serial_port']
        port_identifier = mapping['port_identifier']
        gpio_pins = gpio_pins_per_device.get(port_identifier)
        if not gpio_pins:
            logging.error(f"No GPIO pins defined for {port_identifier}")
            continue
        logging.info(f"Setting up {port_identifier} on {serial_port}")
        t = threading.Thread(target=read_from_fed, args=(serial_port, port_identifier, gpio_pins))
        t.start()
        threads.append(t)

    # Cleanup GPIO when script ends
    try:
        while True:
            time.sleep(1)  # Keep the script running
    except KeyboardInterrupt:
        logging.info("Interrupted by user.")
        stop_event.set()  # Signal threads to stop
    finally:
        # Wait for threads to finish
        for t in threads:
            t.join()
        logging.info("Cleaning up GPIO and exiting.")
        GPIO.cleanup()
# Out:
# 2024-10-08 14:59:44,048 [INFO] Starting device mapping based on USB ports...
# 2024-10-08 14:59:44,051 [DEBUG] Found serial port /dev/ttyACM0 with symlink platform-fd500000.pcie-pci-0000:01:00.0-usb-0:1.1:1.0
# 2024-10-08 14:59:44,057 [INFO] Mapped serial port /dev/ttyACM0 to Port 1 based on USB port usb-0:1.1
# 2024-10-08 14:59:44,060 [DEBUG] Found serial port /dev/ttyACM1 with symlink platform-fd500000.pcie-pci-0000:01:00.0-usb-0:1.2:1.0
# 2024-10-08 14:59:44,063 [INFO] Mapped serial port /dev/ttyACM1 to Port 2 based on USB port usb-0:1.2
# 2024-10-08 14:59:44,070 [DEBUG] Found serial port /dev/ttyACM2 with symlink platform-fd500000.pcie-pci-0000:01:00.0-usb-0:1.4:1.0
# 2024-10-08 14:59:44,076 [INFO] Mapped serial port /dev/ttyACM2 to Port 4 based on USB port usb-0:1.4
# 2024-10-08 14:59:44,078 [DEBUG] Found serial port /dev/ttyACM3 with symlink platform-fd500000.pcie-pci-0000:01:00.0-usb-0:1.3:1.0
# 2024-10-08 14:59:44,087 [INFO] Mapped serial port /dev/ttyACM3 to Port 3 based on USB port usb-0:1.3
# 2024-10-08 14:59:44,089 [INFO] Setting up Port 1 on /dev/ttyACM0
# 2024-10-08 14:59:44,095 [INFO] Setting up Port 2 on /dev/ttyACM1
# 2024-10-08 14:59:44,099 [INFO] Opened serial port /dev/ttyACM0 for Port 1
# 2024-10-08 14:59:44,101 [INFO] Setting up Port 4 on /dev/ttyACM2
# 2024-10-08 14:59:44,113 [INFO] Setting up Port 3 on /dev/ttyACM3
# 2024-10-08 14:59:44,106 [INFO] Opened serial port /dev/ttyACM1 for Port 2
# 2024-10-08 14:59:44,118 [INFO] Opened serial port /dev/ttyACM2 for Port 4
# 2024-10-08 14:59:44,132 [INFO] Opened serial port /dev/ttyACM3 for Port 3
# 2024-10-08 14:59:53,840 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:19', '25.60', '27.38', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'Right', 'Left', '9', '40', '5', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 14:59:53,842 [DEBUG] Port 1: Extracted event type: Right
# 2024-10-08 14:59:53,844 [INFO] [2024-10-08 14:59:53.844] [Port 1] Processing event: Right
# 2024-10-08 14:59:53,847 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 14:59:53,860 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 14:59:55,776 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:20', '25.59', '27.38', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'Right', 'Left', '9', '41', '5', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 14:59:55,778 [DEBUG] Port 1: Extracted event type: Right
# 2024-10-08 14:59:55,780 [INFO] [2024-10-08 14:59:55.780] [Port 1] Processing event: Right
# 2024-10-08 14:59:55,786 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 14:59:55,799 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 14:59:56,507 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:21', '25.61', '27.42', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'Right', 'Left', '9', '42', '5', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 14:59:56,508 [DEBUG] Port 1: Extracted event type: Right
# 2024-10-08 14:59:56,510 [INFO] [2024-10-08 14:59:56.510] [Port 1] Processing event: Right
# 2024-10-08 14:59:56,512 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 14:59:56,526 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 14:59:57,237 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:22', '25.60', '27.41', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'Right', 'Left', '9', '43', '5', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 14:59:57,239 [DEBUG] Port 1: Extracted event type: Right
# 2024-10-08 14:59:57,242 [INFO] [2024-10-08 14:59:57.242] [Port 1] Processing event: Right
# 2024-10-08 14:59:57,245 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 14:59:57,258 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 14:59:57,967 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:23', '25.60', '27.37', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'Right', 'Left', '9', '44', '5', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 14:59:57,969 [DEBUG] Port 1: Extracted event type: Right
# 2024-10-08 14:59:57,970 [INFO] [2024-10-08 14:59:57.970] [Port 1] Processing event: Right
# 2024-10-08 14:59:57,973 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 14:59:57,986 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:00,345 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:25', '25.60', '27.44', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'Left', 'Left', '10', '44', '5', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:00:00,348 [DEBUG] Port 1: Extracted event type: Left
# 2024-10-08 15:00:00,350 [INFO] [2024-10-08 15:00:00.350] [Port 1] Processing event: Left
# 2024-10-08 15:00:00,354 [DEBUG] Sending TTL signal to pin 17
# 2024-10-08 15:00:00,366 [DEBUG] Port 1: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:00:02,669 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:27', '25.59', '27.50', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'PelletInWell', 'Left', '10', '44', '5', '0', 'NaN', 'NaN', 'NaN']
# 2024-10-08 15:00:02,670 [DEBUG] Port 1: Extracted event type: PelletInWell
# 2024-10-08 15:00:02,672 [INFO] [2024-10-08 15:00:02.672] [Port 1] Processing event: PelletInWell
# 2024-10-08 15:00:02,674 [DEBUG] Port 1: Pellet dispensed in well, signal ON.
# 2024-10-08 15:00:08,528 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:33', '25.60', '27.59', '1.16.3', 'FR1', '11', '4.19', 'NaN', '1', 'LeftWithPellet', 'Left', '11', '44', '5', '0', 'NaN', 'NaN', '1.32']
# 2024-10-08 15:00:08,531 [DEBUG] Port 1: Extracted event type: LeftWithPellet
# 2024-10-08 15:00:08,535 [INFO] [2024-10-08 15:00:08.535] [Port 1] Processing event: LeftWithPellet
# 2024-10-08 15:00:08,540 [DEBUG] Sending TTL signal to pin 17
# 2024-10-08 15:00:08,555 [DEBUG] Port 1: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:00:10,065 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:35', '25.59', '27.64', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'LeftWithPellet', 'Left', '12', '44', '5', '0', 'NaN', 'NaN', '0.36']
# 2024-10-08 15:00:10,072 [DEBUG] Port 1: Extracted event type: LeftWithPellet
# 2024-10-08 15:00:10,079 [INFO] [2024-10-08 15:00:10.078] [Port 1] Processing event: LeftWithPellet
# 2024-10-08 15:00:10,082 [DEBUG] Sending TTL signal to pin 17
# 2024-10-08 15:00:10,096 [DEBUG] Port 1: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:00:11,804 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:36', '25.61', '27.66', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '12', '45', '5', '0', 'NaN', 'NaN', '0.49']
# 2024-10-08 15:00:11,807 [DEBUG] Port 1: Extracted event type: RightWithPellet
# 2024-10-08 15:00:11,809 [INFO] [2024-10-08 15:00:11.808] [Port 1] Processing event: RightWithPellet
# 2024-10-08 15:00:11,810 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 15:00:11,823 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:12,700 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:37', '25.60', '27.67', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '12', '46', '5', '0', 'NaN', 'NaN', '0.26']
# 2024-10-08 15:00:12,701 [DEBUG] Port 1: Extracted event type: RightWithPellet
# 2024-10-08 15:00:12,703 [INFO] [2024-10-08 15:00:12.703] [Port 1] Processing event: RightWithPellet
# 2024-10-08 15:00:12,705 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 15:00:12,718 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:13,468 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:38', '25.61', '27.68', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '12', '47', '5', '0', 'NaN', 'NaN', '0.27']
# 2024-10-08 15:00:13,469 [DEBUG] Port 1: Extracted event type: RightWithPellet
# 2024-10-08 15:00:13,471 [INFO] [2024-10-08 15:00:13.470] [Port 1] Processing event: RightWithPellet
# 2024-10-08 15:00:13,472 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 15:00:13,487 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:14,220 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:39', '25.61', '27.65', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '12', '48', '5', '0', 'NaN', 'NaN', '0.25']
# 2024-10-08 15:00:14,223 [DEBUG] Port 1: Extracted event type: RightWithPellet
# 2024-10-08 15:00:14,229 [INFO] [2024-10-08 15:00:14.229] [Port 1] Processing event: RightWithPellet
# 2024-10-08 15:00:14,234 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 15:00:14,252 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:14,945 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:40', '25.62', '27.60', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '12', '49', '5', '0', 'NaN', 'NaN', '0.23']
# 2024-10-08 15:00:14,946 [DEBUG] Port 1: Extracted event type: RightWithPellet
# 2024-10-08 15:00:14,950 [INFO] [2024-10-08 15:00:14.950] [Port 1] Processing event: RightWithPellet
# 2024-10-08 15:00:14,953 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 15:00:14,965 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:15,660 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:40', '25.62', '27.63', '1.16.3', 'FR1', '11', '4.19', 'NaN', '1', 'RightWithPellet', 'Left', '12', '50', '5', '0', 'NaN', 'NaN', '0.29']
# 2024-10-08 15:00:15,661 [DEBUG] Port 1: Extracted event type: RightWithPellet
# 2024-10-08 15:00:15,663 [INFO] [2024-10-08 15:00:15.663] [Port 1] Processing event: RightWithPellet
# 2024-10-08 15:00:15,666 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 15:00:15,679 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:16,337 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:41', '25.63', '27.61', '1.16.3', 'FR1', '11', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '12', '51', '5', '0', 'NaN', 'NaN', '0.25']
# 2024-10-08 15:00:16,339 [DEBUG] Port 1: Extracted event type: RightWithPellet
# 2024-10-08 15:00:16,345 [INFO] [2024-10-08 15:00:16.345] [Port 1] Processing event: RightWithPellet
# 2024-10-08 15:00:16,348 [DEBUG] Sending TTL signal to pin 27
# 2024-10-08 15:00:16,360 [DEBUG] Port 1: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:16,896 [DEBUG] Port 1 raw data: ['10/8/2024 15:55:42', '25.63', '27.58', '1.16.3', 'FR1', '11', '4.20', '2', '1', 'Pellet', 'Left', '12', '51', '6', '0', '14.16', '441', 'NaN']
# 2024-10-08 15:00:16,898 [DEBUG] Port 1: Extracted event type: Pellet
# 2024-10-08 15:00:16,899 [INFO] [2024-10-08 15:00:16.899] [Port 1] Processing event: Pellet
# 2024-10-08 15:00:16,901 [DEBUG] Port 1: Pellet taken, signal turned OFF.
# 2024-10-08 15:00:16,905 [DEBUG] Sending TTL signal to pin 22
# 2024-10-08 15:00:22,614 [DEBUG] Port 2 raw data: ['10/8/2024 15:50:56', '25.57', '29.78', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'Right', 'Left', '5', '42', '3', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:00:22,617 [DEBUG] Port 2: Extracted event type: Right
# 2024-10-08 15:00:22,622 [INFO] [2024-10-08 15:00:22.622] [Port 2] Processing event: Right
# 2024-10-08 15:00:22,626 [DEBUG] Sending TTL signal to pin 9
# 2024-10-08 15:00:22,639 [DEBUG] Port 2: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:23,363 [DEBUG] Port 2 raw data: ['10/8/2024 15:50:57', '25.57', '29.76', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'Right', 'Left', '5', '43', '3', '0', 'NaN', 'NaN', '0.02']
# 2024-10-08 15:00:23,365 [DEBUG] Port 2: Extracted event type: Right
# 2024-10-08 15:00:23,367 [INFO] [2024-10-08 15:00:23.367] [Port 2] Processing event: Right
# 2024-10-08 15:00:23,370 [DEBUG] Sending TTL signal to pin 9
# 2024-10-08 15:00:23,382 [DEBUG] Port 2: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:37,245 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:10', '25.57', '29.78', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'Right', 'Left', '5', '44', '3', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:00:37,248 [DEBUG] Port 2: Extracted event type: Right
# 2024-10-08 15:00:37,251 [INFO] [2024-10-08 15:00:37.251] [Port 2] Processing event: Right
# 2024-10-08 15:00:37,255 [DEBUG] Sending TTL signal to pin 9
# 2024-10-08 15:00:37,273 [DEBUG] Port 2: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:37,855 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:11', '25.57', '29.79', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'Right', 'Left', '5', '45', '3', '0', 'NaN', 'NaN', '0.03']
# 2024-10-08 15:00:37,857 [DEBUG] Port 2: Extracted event type: Right
# 2024-10-08 15:00:37,859 [INFO] [2024-10-08 15:00:37.859] [Port 2] Processing event: Right
# 2024-10-08 15:00:37,861 [DEBUG] Sending TTL signal to pin 9
# 2024-10-08 15:00:37,873 [DEBUG] Port 2: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:39,778 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:13', '25.57', '29.80', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'Right', 'Left', '5', '46', '3', '0', 'NaN', 'NaN', '0.15']
# 2024-10-08 15:00:39,780 [DEBUG] Port 2: Extracted event type: Right
# 2024-10-08 15:00:39,782 [INFO] [2024-10-08 15:00:39.782] [Port 2] Processing event: Right
# 2024-10-08 15:00:39,784 [DEBUG] Sending TTL signal to pin 9
# 2024-10-08 15:00:39,796 [DEBUG] Port 2: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:40,356 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:14', '25.58', '29.80', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'Right', 'Left', '5', '47', '3', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:00:40,358 [DEBUG] Port 2: Extracted event type: Right
# 2024-10-08 15:00:40,360 [INFO] [2024-10-08 15:00:40.360] [Port 2] Processing event: Right
# 2024-10-08 15:00:40,363 [DEBUG] Sending TTL signal to pin 9
# 2024-10-08 15:00:40,375 [DEBUG] Port 2: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:00:45,714 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:19', '25.58', '29.76', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'Left', 'Left', '6', '47', '3', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:00:45,715 [DEBUG] Port 2: Extracted event type: Left
# 2024-10-08 15:00:45,717 [INFO] [2024-10-08 15:00:45.717] [Port 2] Processing event: Left
# 2024-10-08 15:00:45,720 [DEBUG] Sending TTL signal to pin 10
# 2024-10-08 15:00:45,734 [DEBUG] Port 2: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:00:53,602 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:27', '25.55', '29.64', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'PelletInWell', 'Left', '6', '47', '3', '0', 'NaN', 'NaN', 'NaN']
# 2024-10-08 15:00:53,604 [DEBUG] Port 2: Extracted event type: PelletInWell
# 2024-10-08 15:00:53,608 [INFO] [2024-10-08 15:00:53.608] [Port 2] Processing event: PelletInWell
# 2024-10-08 15:00:53,611 [DEBUG] Port 2: Pellet dispensed in well, signal ON.
# 2024-10-08 15:01:08,328 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:42', '25.57', '29.70', '1.16.3', 'FR1', '4', '4.18', 'NaN', '1', 'LeftWithPellet', 'Left', '7', '47', '3', '0', 'NaN', 'NaN', '0.73']
# 2024-10-08 15:01:08,332 [DEBUG] Port 2: Extracted event type: LeftWithPellet
# 2024-10-08 15:01:08,335 [INFO] [2024-10-08 15:01:08.335] [Port 2] Processing event: LeftWithPellet
# 2024-10-08 15:01:08,342 [DEBUG] Sending TTL signal to pin 10
# 2024-10-08 15:01:08,360 [DEBUG] Port 2: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:01:08,879 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:42', '25.59', '29.70', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'LeftWithPellet', 'Left', '8', '47', '3', '0', 'NaN', 'NaN', '0.13']
# 2024-10-08 15:01:08,881 [DEBUG] Port 2: Extracted event type: LeftWithPellet
# 2024-10-08 15:01:08,883 [INFO] [2024-10-08 15:01:08.883] [Port 2] Processing event: LeftWithPellet
# 2024-10-08 15:01:08,885 [DEBUG] Sending TTL signal to pin 10
# 2024-10-08 15:01:08,899 [DEBUG] Port 2: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:01:11,934 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:45', '25.58', '29.73', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'RightWithPellet', 'Left', '8', '48', '3', '0', 'NaN', 'NaN', '1.12']
# 2024-10-08 15:01:11,936 [DEBUG] Port 2: Extracted event type: RightWithPellet
# 2024-10-08 15:01:11,938 [INFO] [2024-10-08 15:01:11.938] [Port 2] Processing event: RightWithPellet
# 2024-10-08 15:01:11,940 [DEBUG] Sending TTL signal to pin 9
# 2024-10-08 15:01:11,953 [DEBUG] Port 2: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:12,938 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:46', '25.58', '29.75', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'RightWithPellet', 'Left', '8', '49', '3', '0', 'NaN', 'NaN', '0.30']
# 2024-10-08 15:01:12,939 [DEBUG] Port 2: Extracted event type: RightWithPellet
# 2024-10-08 15:01:12,941 [INFO] [2024-10-08 15:01:12.941] [Port 2] Processing event: RightWithPellet
# 2024-10-08 15:01:12,942 [DEBUG] Sending TTL signal to pin 9
# 2024-10-08 15:01:12,955 [DEBUG] Port 2: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:13,711 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:47', '25.58', '29.67', '1.16.3', 'FR1', '4', '4.18', 'NaN', '1', 'RightWithPellet', 'Left', '8', '50', '3', '0', 'NaN', 'NaN', '0.28']
# 2024-10-08 15:01:13,713 [DEBUG] Port 2: Extracted event type: RightWithPellet
# 2024-10-08 15:01:13,715 [INFO] [2024-10-08 15:01:13.715] [Port 2] Processing event: RightWithPellet
# 2024-10-08 15:01:13,718 [DEBUG] Sending TTL signal to pin 9
# 2024-10-08 15:01:13,731 [DEBUG] Port 2: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:15,195 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:48', '25.58', '29.65', '1.16.3', 'FR1', '4', '4.19', 'NaN', '1', 'LeftWithPellet', 'Left', '9', '50', '3', '0', 'NaN', 'NaN', '0.30']
# 2024-10-08 15:01:15,198 [DEBUG] Port 2: Extracted event type: LeftWithPellet
# 2024-10-08 15:01:15,204 [INFO] [2024-10-08 15:01:15.204] [Port 2] Processing event: LeftWithPellet
# 2024-10-08 15:01:15,211 [DEBUG] Sending TTL signal to pin 10
# 2024-10-08 15:01:15,226 [DEBUG] Port 2: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:01:15,830 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:49', '25.58', '29.69', '1.16.3', 'FR1', '4', '4.18', 'NaN', '1', 'LeftWithPellet', 'Left', '10', '50', '3', '0', 'NaN', 'NaN', '0.14']
# 2024-10-08 15:01:15,831 [DEBUG] Port 2: Extracted event type: LeftWithPellet
# 2024-10-08 15:01:15,833 [INFO] [2024-10-08 15:01:15.833] [Port 2] Processing event: LeftWithPellet
# 2024-10-08 15:01:15,834 [DEBUG] Sending TTL signal to pin 10
# 2024-10-08 15:01:15,846 [DEBUG] Port 2: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:01:20,448 [DEBUG] Port 2 raw data: ['10/8/2024 15:51:54', '25.57', '29.63', '1.16.3', 'FR1', '4', '4.19', '5', '1', 'Pellet', 'Left', '10', '50', '4', '0', '26.79', '440', 'NaN']
# 2024-10-08 15:01:20,450 [DEBUG] Port 2: Extracted event type: Pellet
# 2024-10-08 15:01:20,451 [INFO] [2024-10-08 15:01:20.451] [Port 2] Processing event: Pellet
# 2024-10-08 15:01:20,452 [DEBUG] Port 2: Pellet taken, signal turned OFF.
# 2024-10-08 15:01:20,458 [DEBUG] Sending TTL signal to pin 11
# 2024-10-08 15:01:29,685 [DEBUG] Port 3 raw data: ['10/8/2024 15:51:57', '25.37', '24.58', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'Right', 'Left', '19', '61', '11', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:01:29,687 [DEBUG] Port 3: Extracted event type: Right
# 2024-10-08 15:01:29,690 [INFO] [2024-10-08 15:01:29.690] [Port 3] Processing event: Right
# 2024-10-08 15:01:29,693 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:01:29,705 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:30,588 [DEBUG] Port 3 raw data: ['10/8/2024 15:51:58', '25.38', '24.59', '1.16.3', 'FR1', '8', '4.19', 'NaN', '1', 'Right', 'Left', '19', '62', '11', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:01:30,590 [DEBUG] Port 3: Extracted event type: Right
# 2024-10-08 15:01:30,591 [INFO] [2024-10-08 15:01:30.591] [Port 3] Processing event: Right
# 2024-10-08 15:01:30,594 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:01:30,607 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:31,342 [DEBUG] Port 3 raw data: ['10/8/2024 15:51:59', '25.39', '24.58', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'Right', 'Left', '19', '63', '11', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:01:31,344 [DEBUG] Port 3: Extracted event type: Right
# 2024-10-08 15:01:31,345 [INFO] [2024-10-08 15:01:31.345] [Port 3] Processing event: Right
# 2024-10-08 15:01:31,347 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:01:31,362 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:32,099 [DEBUG] Port 3 raw data: ['10/8/2024 15:51:59', '25.39', '24.57', '1.16.3', 'FR1', '8', '4.19', 'NaN', '1', 'Right', 'Left', '19', '64', '11', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:01:32,100 [DEBUG] Port 3: Extracted event type: Right
# 2024-10-08 15:01:32,103 [INFO] [2024-10-08 15:01:32.102] [Port 3] Processing event: Right
# 2024-10-08 15:01:32,105 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:01:32,118 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:32,710 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:00', '25.40', '24.56', '1.16.3', 'FR1', '8', '4.19', 'NaN', '1', 'Right', 'Left', '19', '65', '11', '0', 'NaN', 'NaN', '0.01']
# 2024-10-08 15:01:32,712 [DEBUG] Port 3: Extracted event type: Right
# 2024-10-08 15:01:32,714 [INFO] [2024-10-08 15:01:32.714] [Port 3] Processing event: Right
# 2024-10-08 15:01:32,716 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:01:32,729 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:33,464 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:01', '25.40', '24.58', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'Right', 'Left', '19', '66', '11', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:01:33,466 [DEBUG] Port 3: Extracted event type: Right
# 2024-10-08 15:01:33,468 [INFO] [2024-10-08 15:01:33.468] [Port 3] Processing event: Right
# 2024-10-08 15:01:33,471 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:01:33,484 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:34,218 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:02', '25.39', '24.57', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'Right', 'Left', '19', '67', '11', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:01:34,220 [DEBUG] Port 3: Extracted event type: Right
# 2024-10-08 15:01:34,222 [INFO] [2024-10-08 15:01:34.222] [Port 3] Processing event: Right
# 2024-10-08 15:01:34,224 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:01:34,238 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:34,822 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:02', '25.39', '24.56', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'Right', 'Left', '19', '68', '11', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:01:34,823 [DEBUG] Port 3: Extracted event type: Right
# 2024-10-08 15:01:34,825 [INFO] [2024-10-08 15:01:34.825] [Port 3] Processing event: Right
# 2024-10-08 15:01:34,827 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:01:34,839 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:42,171 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:10', '25.39', '24.67', '1.16.3', 'FR1', '8', '4.19', 'NaN', '1', 'Right', 'Left', '19', '69', '11', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:01:42,174 [DEBUG] Port 3: Extracted event type: Right
# 2024-10-08 15:01:42,177 [INFO] [2024-10-08 15:01:42.177] [Port 3] Processing event: Right
# 2024-10-08 15:01:42,179 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:01:42,192 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:42,927 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:10', '25.41', '24.67', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'Right', 'Left', '19', '70', '11', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:01:42,928 [DEBUG] Port 3: Extracted event type: Right
# 2024-10-08 15:01:42,931 [INFO] [2024-10-08 15:01:42.930] [Port 3] Processing event: Right
# 2024-10-08 15:01:42,932 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:01:42,945 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:01:44,579 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:12', '25.39', '24.68', '1.16.3', 'FR1', '8', '4.19', 'NaN', '1', 'Left', 'Left', '20', '70', '11', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:01:44,581 [DEBUG] Port 3: Extracted event type: Left
# 2024-10-08 15:01:44,584 [INFO] [2024-10-08 15:01:44.584] [Port 3] Processing event: Left
# 2024-10-08 15:01:44,592 [DEBUG] Sending TTL signal to pin 0
# 2024-10-08 15:01:44,608 [DEBUG] Port 3: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:01:56,991 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:24', '25.40', '24.78', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'PelletInWell', 'Left', '20', '70', '11', '0', 'NaN', 'NaN', 'NaN']
# 2024-10-08 15:01:56,993 [DEBUG] Port 3: Extracted event type: PelletInWell
# 2024-10-08 15:01:56,995 [INFO] [2024-10-08 15:01:56.995] [Port 3] Processing event: PelletInWell
# 2024-10-08 15:01:56,998 [DEBUG] Port 3: Pellet dispensed in well, signal ON.
# 2024-10-08 15:02:05,085 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:32', '25.41', '24.80', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '20', '71', '11', '0', 'NaN', 'NaN', '0.32']
# 2024-10-08 15:02:05,087 [DEBUG] Port 3: Extracted event type: RightWithPellet
# 2024-10-08 15:02:05,088 [INFO] [2024-10-08 15:02:05.088] [Port 3] Processing event: RightWithPellet
# 2024-10-08 15:02:05,091 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:02:05,103 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:02:05,636 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:33', '25.44', '24.82', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '20', '72', '11', '0', 'NaN', 'NaN', '0.10']
# 2024-10-08 15:02:05,639 [DEBUG] Port 3: Extracted event type: RightWithPellet
# 2024-10-08 15:02:05,642 [INFO] [2024-10-08 15:02:05.642] [Port 3] Processing event: RightWithPellet
# 2024-10-08 15:02:05,645 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:02:05,656 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:02:06,261 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:34', '25.43', '24.84', '1.16.3', 'FR1', '8', '4.19', 'NaN', '1', 'RightWithPellet', 'Left', '20', '73', '11', '0', 'NaN', 'NaN', '0.17']
# 2024-10-08 15:02:06,263 [DEBUG] Port 3: Extracted event type: RightWithPellet
# 2024-10-08 15:02:06,264 [INFO] [2024-10-08 15:02:06.264] [Port 3] Processing event: RightWithPellet
# 2024-10-08 15:02:06,266 [DEBUG] Sending TTL signal to pin 5
# 2024-10-08 15:02:06,278 [DEBUG] Port 3: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:02:07,729 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:35', '25.43', '24.84', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'LeftWithPellet', 'Left', '21', '73', '11', '0', 'NaN', 'NaN', '0.19']
# 2024-10-08 15:02:07,738 [DEBUG] Port 3: Extracted event type: LeftWithPellet
# 2024-10-08 15:02:07,742 [INFO] [2024-10-08 15:02:07.742] [Port 3] Processing event: LeftWithPellet
# 2024-10-08 15:02:07,747 [DEBUG] Sending TTL signal to pin 0
# 2024-10-08 15:02:07,761 [DEBUG] Port 3: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:02:08,482 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:36', '25.43', '24.84', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'LeftWithPellet', 'Left', '22', '73', '11', '0', 'NaN', 'NaN', '0.23']
# 2024-10-08 15:02:08,484 [DEBUG] Port 3: Extracted event type: LeftWithPellet
# 2024-10-08 15:02:08,486 [INFO] [2024-10-08 15:02:08.485] [Port 3] Processing event: LeftWithPellet
# 2024-10-08 15:02:08,487 [DEBUG] Sending TTL signal to pin 0
# 2024-10-08 15:02:08,501 [DEBUG] Port 3: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:02:09,489 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:37', '25.41', '24.80', '1.16.3', 'FR1', '8', '4.20', 'NaN', '1', 'LeftWithPellet', 'Left', '23', '73', '11', '0', 'NaN', 'NaN', '0.55']
# 2024-10-08 15:02:09,491 [DEBUG] Port 3: Extracted event type: LeftWithPellet
# 2024-10-08 15:02:09,494 [INFO] [2024-10-08 15:02:09.494] [Port 3] Processing event: LeftWithPellet
# 2024-10-08 15:02:09,500 [DEBUG] Sending TTL signal to pin 0
# 2024-10-08 15:02:09,514 [DEBUG] Port 3: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:02:13,573 [DEBUG] Port 3 raw data: ['10/8/2024 15:52:41', '25.42', '24.79', '1.16.3', 'FR1', '8', '4.20', '7', '1', 'Pellet', 'Left', '23', '73', '12', '0', '16.54', '7010', 'NaN']
# 2024-10-08 15:02:13,575 [DEBUG] Port 3: Extracted event type: Pellet
# 2024-10-08 15:02:13,577 [INFO] [2024-10-08 15:02:13.577] [Port 3] Processing event: Pellet
# 2024-10-08 15:02:13,578 [DEBUG] Port 3: Pellet taken, signal turned OFF.
# 2024-10-08 15:02:13,582 [DEBUG] Sending TTL signal to pin 6
# 2024-10-08 15:02:16,893 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:23', '24.85', '24.87', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'Right', 'Left', '22', '77', '9', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:02:16,894 [DEBUG] Port 4: Extracted event type: Right
# 2024-10-08 15:02:16,896 [INFO] [2024-10-08 15:02:16.896] [Port 4] Processing event: Right
# 2024-10-08 15:02:16,899 [DEBUG] Sending TTL signal to pin 19
# 2024-10-08 15:02:16,911 [DEBUG] Port 4: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:02:17,673 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:24', '24.86', '24.84', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'Right', 'Left', '22', '78', '9', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:02:17,674 [DEBUG] Port 4: Extracted event type: Right
# 2024-10-08 15:02:17,676 [INFO] [2024-10-08 15:02:17.676] [Port 4] Processing event: Right
# 2024-10-08 15:02:17,679 [DEBUG] Sending TTL signal to pin 19
# 2024-10-08 15:02:17,694 [DEBUG] Port 4: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:02:18,605 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:25', '24.86', '24.84', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'Right', 'Left', '22', '79', '9', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:02:18,606 [DEBUG] Port 4: Extracted event type: Right
# 2024-10-08 15:02:18,608 [INFO] [2024-10-08 15:02:18.608] [Port 4] Processing event: Right
# 2024-10-08 15:02:18,611 [DEBUG] Sending TTL signal to pin 19
# 2024-10-08 15:02:18,623 [DEBUG] Port 4: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:02:19,239 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:25', '24.85', '24.85', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'Right', 'Left', '22', '80', '9', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:02:19,241 [DEBUG] Port 4: Extracted event type: Right
# 2024-10-08 15:02:19,243 [INFO] [2024-10-08 15:02:19.242] [Port 4] Processing event: Right
# 2024-10-08 15:02:19,245 [DEBUG] Sending TTL signal to pin 19
# 2024-10-08 15:02:19,259 [DEBUG] Port 4: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:02:26,634 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:33', '24.85', '24.89', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'Left', 'Left', '23', '80', '9', '0', 'NaN', 'NaN', '0.00']
# 2024-10-08 15:02:26,637 [DEBUG] Port 4: Extracted event type: Left
# 2024-10-08 15:02:26,641 [INFO] [2024-10-08 15:02:26.641] [Port 4] Processing event: Left
# 2024-10-08 15:02:26,644 [DEBUG] Sending TTL signal to pin 13
# 2024-10-08 15:02:26,658 [DEBUG] Port 4: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:02:29,259 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:35', '24.84', '24.91', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'PelletInWell', 'Left', '23', '80', '9', '0', 'NaN', 'NaN', 'NaN']
# 2024-10-08 15:02:29,260 [DEBUG] Port 4: Extracted event type: PelletInWell
# 2024-10-08 15:02:29,262 [INFO] [2024-10-08 15:02:29.262] [Port 4] Processing event: PelletInWell
# 2024-10-08 15:02:29,264 [DEBUG] Port 4: Pellet dispensed in well, signal ON.
# 2024-10-08 15:02:35,401 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:42', '24.82', '24.93', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '23', '81', '9', '0', 'NaN', 'NaN', '0.39']
# 2024-10-08 15:02:35,404 [DEBUG] Port 4: Extracted event type: RightWithPellet
# 2024-10-08 15:02:35,407 [INFO] [2024-10-08 15:02:35.407] [Port 4] Processing event: RightWithPellet
# 2024-10-08 15:02:35,410 [DEBUG] Sending TTL signal to pin 19
# 2024-10-08 15:02:35,429 [DEBUG] Port 4: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:02:36,229 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:42', '24.85', '24.94', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '23', '82', '9', '0', 'NaN', 'NaN', '0.35']
# 2024-10-08 15:02:36,231 [DEBUG] Port 4: Extracted event type: RightWithPellet
# 2024-10-08 15:02:36,233 [INFO] [2024-10-08 15:02:36.233] [Port 4] Processing event: RightWithPellet
# 2024-10-08 15:02:36,236 [DEBUG] Sending TTL signal to pin 19
# 2024-10-08 15:02:36,250 [DEBUG] Port 4: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:02:37,381 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:43', '24.85', '24.95', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '23', '83', '9', '0', 'NaN', 'NaN', '0.40']
# 2024-10-08 15:02:37,383 [DEBUG] Port 4: Extracted event type: RightWithPellet
# 2024-10-08 15:02:37,384 [INFO] [2024-10-08 15:02:37.384] [Port 4] Processing event: RightWithPellet
# 2024-10-08 15:02:37,388 [DEBUG] Sending TTL signal to pin 19
# 2024-10-08 15:02:37,401 [DEBUG] Port 4: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:02:38,125 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:44', '24.84', '24.97', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'RightWithPellet', 'Left', '23', '84', '9', '0', 'NaN', 'NaN', '0.27']
# 2024-10-08 15:02:38,126 [DEBUG] Port 4: Extracted event type: RightWithPellet
# 2024-10-08 15:02:38,128 [INFO] [2024-10-08 15:02:38.128] [Port 4] Processing event: RightWithPellet
# 2024-10-08 15:02:38,130 [DEBUG] Sending TTL signal to pin 19
# 2024-10-08 15:02:38,144 [DEBUG] Port 4: Right poke event (with or without pellet) triggered.
# 2024-10-08 15:02:41,565 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:48', '24.84', '24.97', '1.16.3', 'FR1', '20', '4.19', 'NaN', '1', 'LeftWithPellet', 'Left', '24', '84', '9', '0', 'NaN', 'NaN', '0.49']
# 2024-10-08 15:02:41,569 [DEBUG] Port 4: Extracted event type: LeftWithPellet
# 2024-10-08 15:02:41,572 [INFO] [2024-10-08 15:02:41.572] [Port 4] Processing event: LeftWithPellet
# 2024-10-08 15:02:41,575 [DEBUG] Sending TTL signal to pin 13
# 2024-10-08 15:02:41,591 [DEBUG] Port 4: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:02:42,386 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:48', '24.85', '24.98', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'LeftWithPellet', 'Left', '25', '84', '9', '0', 'NaN', 'NaN', '0.21']
# 2024-10-08 15:02:42,388 [DEBUG] Port 4: Extracted event type: LeftWithPellet
# 2024-10-08 15:02:42,390 [INFO] [2024-10-08 15:02:42.390] [Port 4] Processing event: LeftWithPellet
# 2024-10-08 15:02:42,392 [DEBUG] Sending TTL signal to pin 13
# 2024-10-08 15:02:42,404 [DEBUG] Port 4: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:02:50,086 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:56', '24.82', '24.98', '1.16.3', 'FR1', '20', '4.20', 'NaN', '1', 'LeftWithPellet', 'Left', '26', '84', '9', '0', 'NaN', 'NaN', '0.34']
# 2024-10-08 15:02:50,088 [DEBUG] Port 4: Extracted event type: LeftWithPellet
# 2024-10-08 15:02:50,091 [INFO] [2024-10-08 15:02:50.091] [Port 4] Processing event: LeftWithPellet
# 2024-10-08 15:02:50,095 [DEBUG] Sending TTL signal to pin 13
# 2024-10-08 15:02:50,108 [DEBUG] Port 4: Left poke event (with or without pellet) triggered.
# 2024-10-08 15:02:51,044 [DEBUG] Port 4 raw data: ['10/8/2024 15:45:57', '24.83', '24.97', '1.16.3', 'FR1', '20', '4.20', '2', '1', 'Pellet', 'Left', '26', '84', '10', '0', '21.73', '758', 'NaN']
# 2024-10-08 15:02:51,046 [DEBUG] Port 4: Extracted event type: Pellet
# 2024-10-08 15:02:51,050 [INFO] [2024-10-08 15:02:51.049] [Port 4] Processing event: Pellet
# 2024-10-08 15:02:51,052 [DEBUG] Port 4: Pellet taken, signal turned OFF.
# 2024-10-08 15:02:51,056 [DEBUG] Sending TTL signal to pin 26
# 2024-10-08 15:02:56,710 [INFO] Interrupted by user.
# 2024-10-08 15:02:57,083 [INFO] Serial port /dev/ttyACM2 for Port 4 closed.
# 2024-10-08 15:02:57,089 [INFO] Serial port /dev/ttyACM2 for Port 4 closed.
# 2024-10-08 15:02:57,116 [INFO] Serial port /dev/ttyACM0 for Port 1 closed.
# 2024-10-08 15:02:57,120 [INFO] Serial port /dev/ttyACM0 for Port 1 closed.
# 2024-10-08 15:02:57,587 [INFO] Serial port /dev/ttyACM1 for Port 2 closed.
# 2024-10-08 15:02:57,589 [INFO] Serial port /dev/ttyACM1 for Port 2 closed.
# 2024-10-08 15:02:57,653 [INFO] Serial port /dev/ttyACM3 for Port 3 closed.
# 2024-10-08 15:02:57,656 [INFO] Serial port /dev/ttyACM3 for Port 3 closed.
# 2024-10-08 15:02:57,659 [INFO] Cleaning up GPIO and exiting.
